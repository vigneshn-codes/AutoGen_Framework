# %% [markdown]
# # 15. Observing Team Agents
#
# In notebook 05 we watched **one** agent work live.
# Now we watch a **whole team** work live — see each member speak, in order, as it happens.
#
# This is the best way to **understand** how a team reaches its answer.

# %% [markdown]
# ## Real-life analogy
#
# Observing a team is like **sitting in on a group discussion**:
#
# - You hear the **writer** speak, then the **reviewer** reply, then the writer again...
# - You follow the whole back-and-forth until they finish.
#
# The `Console` helper prints this conversation live for us.

# %% [markdown]
# ## How to observe a team
#
# | Want | Code |
# |------|------|
# | Just the final result | `await team.run(task=...)` |
# | Watch every member live | `await Console(team.run_stream(task=...))` |
#
# It is the **same `Console`** from notebook 05 — it works for teams too.

# %%
from dotenv import load_dotenv
load_dotenv()

from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.conditions import TextMentionTermination, MaxMessageTermination
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import OpenAIChatCompletionClient

model_client = OpenAIChatCompletionClient(model="gpt-4o-mini")

idea_agent = AssistantAgent(name="idea_agent", model_client=model_client,
                            system_message="Suggest one simple business idea, or improve it if asked.")
critic = AssistantAgent(name="critic", model_client=model_client,
                        system_message="If the idea is realistic, reply APPROVE. Else suggest one improvement.")

team = RoundRobinGroupChat(
    [idea_agent, critic],
    termination_condition=TextMentionTermination("APPROVE") | MaxMessageTermination(6),
)

# Watch the WHOLE TEAM work live, member by member
await Console(team.run_stream(task="Give me a small business idea for a college student."))
# Out:
# ---------- TextMessage (user) ----------
# Give me a small business idea for a college student.
# ---------- TextMessage (idea_agent) ----------
# A great small business idea for a college student is a "Campus Care Package" service. You can create and deliver custom care packages filled with snacks, study supplies, and personal touches (like handwritten notes) to students who may be feeling homesick or overwhelmed during exams.
#
# To start, consider these steps:
# 1. **Market Research**: Find out what items students appreciate the most and what price points are reasonable for your target audience.
# 2. **Supply Sourcing**: Partner with local vendors or buy items in bulk to keep costs low.
# 3. **Marketing**: Use social media and campus bulletin boards to promote your service, especially during exam weeks or holidays.
# 4. **Delivery Options**: Offer delivery directly to dorm rooms or provide a pickup option.
# ...

# %% [markdown]
# ## Key points to remember
#
# - You can **observe a whole team** live, not just one agent.
# - Use **`await Console(team.run_stream(task=...))`** — the same `Console` as notebook 05.
# - You see each member speak **in order**, as it happens.
# - This makes it easy to **understand and debug** how the team reached its answer.
